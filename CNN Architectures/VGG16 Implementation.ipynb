# %% [markdown]
# ## CIFAR-10 Classification Using VGG16 CNN Model
# ### <u>About VGG16 Architecture</u>
# - VGG model stands for the Visual Geometry Group
# - VGG16 is a convolutional neural network model proposed by K. Simonyan and A. Zisserman
# - This model achieves 92.7% top-5 test accuracy on ImageNet dataset which contains 14 million images belonging to 1000 classes.
# ![Architecture](https://neurohive.io/wp-content/uploads/2018/11/vgg16-1-e1542731207177.png)

# %%
# Required Libraries
import warnings
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from skimage import transform

print(tf.__version__)
warnings.filterwarnings("ignore")
# Out:
# 2.4.1

# %%
# Load Dataset
cifar = tf.keras.datasets.cifar10
(X_train, y_train), (X_test, y_test) = cifar.load_data()

print(f'Training set: {X_train.shape}')
print(f'Testing set: {X_test.shape}')
# Out:
# Training set: (50000, 32, 32, 3)
# Testing set: (10000, 32, 32, 3)

# %%
# One hot encoding
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# %%
# Plotting sample images using plt.imshow()
label_dict = {0:'airplane', 1:'automobile', 2:'bird', 3:'cat', 4:'deer',5:'dog',6:'frog', 7:'horse', 8:'ship', 9:'truck'}

def show_image(idx):
  index = y_train[idx][0]
  plt.figure(figsize=(1, 1))
  plt.xlabel(label_dict.get(index))
  plt.imshow(X_train[idx]);

# %%
show_image(0)

# %%
show_image(1000)

# %% [markdown]
# - Not necessary to rescale images: https://stackoverflow.com/questions/56645556/image-size-issue-to-train-cifar-dateset-by-standard-mobilenet-vgg-16-or-alexnet

# %% [markdown]
# ## Model
# ![](https://www.googleapis.com/download/storage/v1/b/kaggle-forum-message-attachments/o/inbox%2F5066898%2Fd56c89bbad2c59261b7c51c160e3d7b7%2FVGG16_Summary-Table.jpg?generation=1598797630439321&alt=media)

# %%
# Input
input = tf.keras.Input(shape =(32, 32, 3))

# 1st Conv Block
x = tf.keras.layers.Conv2D(filters =64, kernel_size =3, padding ='same', activation='relu')(input)
x = tf.keras.layers.Conv2D(filters =64, kernel_size =3, padding ='same', activation='relu')(x)
x = tf.keras.layers.MaxPool2D(pool_size =2, strides =2, padding ='same')(x)

# 2nd Conv Block
x = tf.keras.layers.Conv2D(filters =128, kernel_size =3, padding ='same', activation='relu')(x)
x = tf.keras.layers.Conv2D(filters =128, kernel_size =3, padding ='same', activation='relu')(x)
x = tf.keras.layers.MaxPool2D(pool_size =2, strides =2, padding ='same')(x)

# 3rd Conv block
x = tf.keras.layers.Conv2D(filters =256, kernel_size =3, padding ='same', activation='relu')(x)
x = tf.keras.layers.Conv2D(filters =256, kernel_size =3, padding ='same', activation='relu')(x)
x = tf.keras.layers.Conv2D(filters =256, kernel_size =3, padding ='same', activation='relu')(x)
x = tf.keras.layers.MaxPool2D(pool_size =2, strides =2, padding ='same')(x)

# 4th Conv block
x = tf.keras.layers.Conv2D(filters =512, kernel_size =3, padding ='same', activation='relu')(x)
x = tf.keras.layers.Conv2D(filters =512, kernel_size =3, padding ='same', activation='relu')(x)
x = tf.keras.layers.Conv2D(filters =512, kernel_size =3, padding ='same', activation='relu')(x)
x = tf.keras.layers.MaxPool2D(pool_size =2, strides =2, padding ='same')(x)

# 5th Conv block
x = tf.keras.layers.Conv2D(filters =512, kernel_size =3, padding ='same', activation='relu')(x)
x = tf.keras.layers.Conv2D(filters =512, kernel_size =3, padding ='same', activation='relu')(x)
x = tf.keras.layers.Conv2D(filters =512, kernel_size =3, padding ='same', activation='relu')(x)
x = tf.keras.layers.MaxPool2D(pool_size =2, strides =2, padding ='same')(x)

# Fully connected layers
x = tf.keras.layers.Flatten()(x)
x = tf.keras.layers.Dense(units = 4096, activation ='relu')(x)
x = tf.keras.layers.Dense(units = 4096, activation ='relu')(x)
output = tf.keras.layers.Dense(units = 10, activation ='softmax')(x)

# Creating the model
model = tf.keras.Model(input, outputs=output)
model.compile(loss = "categorical_crossentropy", optimizer = tf.keras.optimizers.SGD(lr=0.001, momentum=0.9), metrics = ["accuracy"])

# %%
train_generator = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255,shear_range=0.1,zoom_range=0.15,horizontal_flip=True)
test_generator  = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

# %%
# Training the Model
history = model.fit_generator(train_generator.flow(X_train, y_train, batch_size=100),
                              steps_per_epoch=X_train.shape[0] // 100,
                              validation_data=test_generator.flow(X_test, y_test, batch_size=100), 
                              epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 500/500 [==============================] - 22s 41ms/step - loss: 2.3025 - accuracy: 0.1022 - val_loss: 2.3024 - val_accuracy: 0.1069
# Epoch 2/100
# 500/500 [==============================] - 20s 40ms/step - loss: 2.3023 - accuracy: 0.1067 - val_loss: 2.3021 - val_accuracy: 0.1333
# Epoch 3/100
# 500/500 [==============================] - 20s 40ms/step - loss: 2.3020 - accuracy: 0.1278 - val_loss: 2.3016 - val_accuracy: 0.1585
# Epoch 4/100
# 500/500 [==============================] - 20s 40ms/step - loss: 2.3014 - accuracy: 0.1369 - val_loss: 2.3001 - val_accuracy: 0.1691
# Epoch 5/100
# 500/500 [==============================] - 20s 40ms/step - loss: 2.2993 - accuracy: 0.1714 - val_loss: 2.2942 - val_accuracy: 0.1888
# Epoch 6/100
# 500/500 [==============================] - 20s 40ms/step - loss: 2.2894 - accuracy: 0.1870 - val_loss: 2.2519 - val_accuracy: 0.1837
# Epoch 7/100
# 500/500 [==============================] - 20s 39ms/step - loss: 2.1991 - accuracy: 0.1819 - val_loss: 2.0950 - val_accuracy: 0.2027
# Epoch 8/100
# 500/500 [==============================] - 20s 39ms/step - loss: 2.0872 - accuracy: 0.1980 - val_loss: 2.0093 - val_accuracy: 0.2122
# Epoch 9/100
# 500/500 [==============================] - 20s 40ms/step - loss: 2.0074 - accuracy: 0.2102 - val_loss: 1.9126 - val_accuracy: 0.2382
# Epoch 10/100
# 500/500 [==============================] - 20s 39ms/step - loss: 1.9313 - accuracy: 0.2263 - val_loss: 1.8556 - val_accuracy: 0.2500
# Epoch 11/100
# 500/500 [==============================] - 20s 39ms/step - loss: 1.8848 - accuracy: 0.2463 - val_loss: 1.8205 - val_accuracy: 0.2691
# Epoch 12/100
# 500/500 [==============================] - 20s 40ms/step - loss: 1.8486 - accuracy: 0.2695 - val_loss: 1.8213 - val_accuracy: 0.2760
# Epoch 13/100
# 500/500 [==============================] - 20s 39ms/step - loss: 1.8116 - accuracy: 0.2935 - val_loss: 1.7436 - val_accuracy: 0.3395
# Epoch 14/100
# 500/500 [==============================] - 20s 39ms/step - loss: 1.7751 - accuracy: 0.3198 - val_loss: 1.7049 - val_accuracy: 0.3464
# Epoch 15/100
# 500/500 [==============================] - 20s 40ms/step - loss: 1.7315 - accuracy: 0.3376 - val_loss: 1.6724 - val_accuracy: 0.3638
# Epoch 16/100
# 500/500 [==============================] - 20s 39ms/step - loss: 1.6905 - accuracy: 0.3520 - val_loss: 1.6128 - val_accuracy: 0.3966
# Epoch 17/100
# 500/500 [==============================] - 20s 39ms/step - loss: 1.6416 - accuracy: 0.3766 - val_loss: 1.5874 - val_accuracy: 0.4055
# Epoch 18/100
# 500/500 [==============================] - 20s 40ms/step - loss: 1.6132 - accuracy: 0.3919 - val_loss: 1.5236 - val_accuracy: 0.4292
# Epoch 19/100
# 500/500 [==============================] - 20s 39ms/step - loss: 1.5751 - accuracy: 0.4092 - val_loss: 1.5640 - val_accuracy: 0.4162
# Epoch 20/100
# 500/500 [==============================] - 20s 40ms/step - loss: 1.5126 - accuracy: 0.4345 - val_loss: 1.4386 - val_accuracy: 0.4562
# Epoch 21/100
# 500/500 [==============================] - 20s 40ms/step - loss: 1.4407 - accuracy: 0.4647 - val_loss: 1.3278 - val_accuracy: 0.5074
# Epoch 22/100
# 500/500 [==============================] - 20s 40ms/step - loss: 1.3859 - accuracy: 0.4879 - val_loss: 1.4171 - val_accuracy: 0.4701
# Epoch 23/100
# 500/500 [==============================] - 20s 40ms/step - loss: 1.3179 - accuracy: 0.5154 - val_loss: 1.3038 - val_accuracy: 0.5221
# Epoch 24/100
# 500/500 [==============================] - 20s 40ms/step - loss: 1.2670 - accuracy: 0.5365 - val_loss: 1.2292 - val_accuracy: 0.5500
# Epoch 25/100
# 500/500 [==============================] - 20s 39ms/step - loss: 1.2156 - accuracy: 0.5554 - val_loss: 1.1460 - val_accuracy: 0.5785
# Epoch 26/100
# 500/500 [==============================] - 20s 40ms/step - loss: 1.1604 - accuracy: 0.5722 - val_loss: 1.1941 - val_accuracy: 0.5666
# Epoch 27/100
# 500/500 [==============================] - 20s 40ms/step - loss: 1.1224 - accuracy: 0.5890 - val_loss: 1.0720 - val_accuracy: 0.6130
# Epoch 28/100
# 500/500 [==============================] - 20s 40ms/step - loss: 1.0740 - accuracy: 0.6100 - val_loss: 1.0007 - val_accuracy: 0.6421
# Epoch 29/100
# 500/500 [==============================] - 20s 40ms/step - loss: 1.0474 - accuracy: 0.6170 - val_loss: 0.9814 - val_accuracy: 0.6483
# Epoch 30/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.9856 - accuracy: 0.6424 - val_loss: 0.9795 - val_accuracy: 0.6430
# Epoch 31/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.9770 - accuracy: 0.6440 - val_loss: 0.9513 - val_accuracy: 0.6578
# Epoch 32/100
# 500/500 [==============================] - 20s 39ms/step - loss: 0.9281 - accuracy: 0.6610 - val_loss: 0.9546 - val_accuracy: 0.6577
# Epoch 33/100
# 500/500 [==============================] - 20s 39ms/step - loss: 0.9045 - accuracy: 0.6732 - val_loss: 0.8830 - val_accuracy: 0.6878
# Epoch 34/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.8606 - accuracy: 0.6891 - val_loss: 0.8723 - val_accuracy: 0.6851
# Epoch 35/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.8393 - accuracy: 0.6962 - val_loss: 0.8325 - val_accuracy: 0.7042
# Epoch 36/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.8137 - accuracy: 0.7074 - val_loss: 0.8266 - val_accuracy: 0.7126
# Epoch 37/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.7882 - accuracy: 0.7140 - val_loss: 0.8307 - val_accuracy: 0.7122
# Epoch 38/100
# 500/500 [==============================] - 20s 39ms/step - loss: 0.7683 - accuracy: 0.7263 - val_loss: 0.7961 - val_accuracy: 0.7238
# Epoch 39/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.7286 - accuracy: 0.7380 - val_loss: 0.7712 - val_accuracy: 0.7267
# Epoch 40/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.7107 - accuracy: 0.7441 - val_loss: 0.8238 - val_accuracy: 0.7171
# Epoch 41/100
# 500/500 [==============================] - 20s 39ms/step - loss: 0.6879 - accuracy: 0.7578 - val_loss: 0.7248 - val_accuracy: 0.7509
# Epoch 42/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.6461 - accuracy: 0.7678 - val_loss: 0.6995 - val_accuracy: 0.7560
# Epoch 43/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.6221 - accuracy: 0.7796 - val_loss: 0.7458 - val_accuracy: 0.7428
# Epoch 44/100
# 500/500 [==============================] - 20s 39ms/step - loss: 0.6111 - accuracy: 0.7833 - val_loss: 0.7238 - val_accuracy: 0.7473
# Epoch 45/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.5888 - accuracy: 0.7894 - val_loss: 0.6808 - val_accuracy: 0.7638
# Epoch 46/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.5728 - accuracy: 0.7953 - val_loss: 0.6499 - val_accuracy: 0.7744
# Epoch 47/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.5535 - accuracy: 0.8046 - val_loss: 0.6353 - val_accuracy: 0.7798
# Epoch 48/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.5359 - accuracy: 0.8122 - val_loss: 0.6443 - val_accuracy: 0.7769
# Epoch 49/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.5093 - accuracy: 0.8214 - val_loss: 0.6319 - val_accuracy: 0.7758
# Epoch 50/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.4891 - accuracy: 0.8274 - val_loss: 0.6302 - val_accuracy: 0.7904
# Epoch 51/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.4750 - accuracy: 0.8325 - val_loss: 0.6184 - val_accuracy: 0.7955
# Epoch 52/100
# 500/500 [==============================] - 20s 39ms/step - loss: 0.4589 - accuracy: 0.8402 - val_loss: 0.6086 - val_accuracy: 0.7956
# Epoch 53/100
# 500/500 [==============================] - 20s 39ms/step - loss: 0.4499 - accuracy: 0.8440 - val_loss: 0.5813 - val_accuracy: 0.8059
# Epoch 54/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.4330 - accuracy: 0.8452 - val_loss: 0.6280 - val_accuracy: 0.7936
# Epoch 55/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.4170 - accuracy: 0.8502 - val_loss: 0.6786 - val_accuracy: 0.7754
# Epoch 56/100
# 500/500 [==============================] - 20s 39ms/step - loss: 0.3876 - accuracy: 0.8614 - val_loss: 0.6106 - val_accuracy: 0.7995
# Epoch 57/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.3757 - accuracy: 0.8686 - val_loss: 0.6134 - val_accuracy: 0.8020
# Epoch 58/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.3642 - accuracy: 0.8726 - val_loss: 0.6077 - val_accuracy: 0.8036
# Epoch 59/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.3491 - accuracy: 0.8775 - val_loss: 0.6613 - val_accuracy: 0.7914
# Epoch 60/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.3393 - accuracy: 0.8811 - val_loss: 0.5989 - val_accuracy: 0.8051
# Epoch 61/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.3222 - accuracy: 0.8869 - val_loss: 0.6634 - val_accuracy: 0.7951
# Epoch 62/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.3054 - accuracy: 0.8943 - val_loss: 0.6394 - val_accuracy: 0.8006
# Epoch 63/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.3057 - accuracy: 0.8927 - val_loss: 0.6109 - val_accuracy: 0.8090
# Epoch 64/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.2841 - accuracy: 0.8990 - val_loss: 0.6233 - val_accuracy: 0.8071
# Epoch 65/100
# 500/500 [==============================] - 20s 39ms/step - loss: 0.2772 - accuracy: 0.9029 - val_loss: 0.6864 - val_accuracy: 0.7922
# Epoch 66/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.2703 - accuracy: 0.9050 - val_loss: 0.6754 - val_accuracy: 0.8044
# Epoch 67/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.2477 - accuracy: 0.9129 - val_loss: 0.7155 - val_accuracy: 0.7963
# Epoch 68/100
# 500/500 [==============================] - 20s 39ms/step - loss: 0.2475 - accuracy: 0.9130 - val_loss: 0.6279 - val_accuracy: 0.8129
# Epoch 69/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.2228 - accuracy: 0.9223 - val_loss: 0.6471 - val_accuracy: 0.8114
# Epoch 70/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.2161 - accuracy: 0.9227 - val_loss: 0.6902 - val_accuracy: 0.8123
# Epoch 71/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.2091 - accuracy: 0.9273 - val_loss: 0.6894 - val_accuracy: 0.8122
# Epoch 72/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.2042 - accuracy: 0.9286 - val_loss: 0.6625 - val_accuracy: 0.8144
# Epoch 73/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1975 - accuracy: 0.9297 - val_loss: 0.6893 - val_accuracy: 0.8156
# Epoch 74/100
# 500/500 [==============================] - 20s 39ms/step - loss: 0.1830 - accuracy: 0.9352 - val_loss: 0.6669 - val_accuracy: 0.8173
# Epoch 75/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1769 - accuracy: 0.9371 - val_loss: 0.6730 - val_accuracy: 0.8123
# Epoch 76/100
# 500/500 [==============================] - 20s 39ms/step - loss: 0.1719 - accuracy: 0.9379 - val_loss: 0.6996 - val_accuracy: 0.8139
# Epoch 77/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1701 - accuracy: 0.9394 - val_loss: 0.6627 - val_accuracy: 0.8182
# Epoch 78/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1509 - accuracy: 0.9469 - val_loss: 0.7049 - val_accuracy: 0.8181
# Epoch 79/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1578 - accuracy: 0.9439 - val_loss: 0.6766 - val_accuracy: 0.8194
# Epoch 80/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1506 - accuracy: 0.9466 - val_loss: 0.6873 - val_accuracy: 0.8182
# Epoch 81/100
# 500/500 [==============================] - 20s 39ms/step - loss: 0.1403 - accuracy: 0.9505 - val_loss: 0.7181 - val_accuracy: 0.8223
# Epoch 82/100
# 500/500 [==============================] - 20s 39ms/step - loss: 0.1294 - accuracy: 0.9536 - val_loss: 0.7105 - val_accuracy: 0.8185
# Epoch 83/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1209 - accuracy: 0.9576 - val_loss: 0.7151 - val_accuracy: 0.8204
# Epoch 84/100
# 500/500 [==============================] - 20s 39ms/step - loss: 0.1190 - accuracy: 0.9588 - val_loss: 0.7396 - val_accuracy: 0.8101
# Epoch 85/100
# 500/500 [==============================] - 20s 39ms/step - loss: 0.1154 - accuracy: 0.9582 - val_loss: 0.7112 - val_accuracy: 0.8268
# Epoch 86/100
# 500/500 [==============================] - 20s 39ms/step - loss: 0.1151 - accuracy: 0.9586 - val_loss: 0.7229 - val_accuracy: 0.8238
# Epoch 87/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1026 - accuracy: 0.9647 - val_loss: 0.7486 - val_accuracy: 0.8172
# Epoch 88/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1043 - accuracy: 0.9637 - val_loss: 0.7955 - val_accuracy: 0.8122
# Epoch 89/100
# 500/500 [==============================] - 20s 39ms/step - loss: 0.1058 - accuracy: 0.9631 - val_loss: 0.7687 - val_accuracy: 0.8197
# Epoch 90/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.0975 - accuracy: 0.9654 - val_loss: 0.7601 - val_accuracy: 0.8165
# Epoch 91/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.0926 - accuracy: 0.9670 - val_loss: 0.7825 - val_accuracy: 0.8148
# Epoch 92/100
# 500/500 [==============================] - 20s 39ms/step - loss: 0.0884 - accuracy: 0.9697 - val_loss: 0.8021 - val_accuracy: 0.8155
# Epoch 93/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.0934 - accuracy: 0.9676 - val_loss: 0.7945 - val_accuracy: 0.8234
# Epoch 94/100
# 500/500 [==============================] - 20s 39ms/step - loss: 0.0832 - accuracy: 0.9709 - val_loss: 0.7897 - val_accuracy: 0.8171
# Epoch 95/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.0916 - accuracy: 0.9678 - val_loss: 0.8163 - val_accuracy: 0.8197
# Epoch 96/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.0719 - accuracy: 0.9744 - val_loss: 0.8024 - val_accuracy: 0.8235
# Epoch 97/100
# 500/500 [==============================] - 20s 39ms/step - loss: 0.0749 - accuracy: 0.9737 - val_loss: 0.8313 - val_accuracy: 0.8247
# Epoch 98/100
# 500/500 [==============================] - 20s 40ms/step - loss: 0.0754 - accuracy: 0.9728 - val_loss: 0.8380 - val_accuracy: 0.8193
# Epoch 99/100
# 500/500 [==============================] - 20s 41ms/step - loss: 0.0682 - accuracy: 0.9760 - val_loss: 0.8557 - val_accuracy: 0.8212
# Epoch 100/100
# 500/500 [==============================] - 20s 41ms/step - loss: 0.0679 - accuracy: 0.9769 - val_loss: 0.9045 - val_accuracy: 0.8145

# %%
training_history = pd.DataFrame(history.history)
training_history.columns = ['Train Loss', 'Train Accuracy', 'Test Loss', 'Test Accuracy']

# Plotting Scores
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 5))

ax1.plot(training_history[['Train Loss', 'Test Loss']]);
ax1.title.set_text('Train loss V/S Test loss')
ax1.set_xlabel('Epochs');
ax1.set_ylabel('Loss');
ax1.legend('best', labels=['Train', 'Test']);
ax1.grid(color = 'green', linestyle = '--', linewidth = 0.5);

ax2.plot(training_history[['Train Accuracy', 'Test Accuracy']]);
ax2.title.set_text('Train accuracy V/S Test accuracy')
ax2.set_xlabel('Epochs');
ax2.set_ylabel('Accuracy');
ax2.legend('best', labels=['Train', 'Test']);
ax2.grid(color = 'green', linestyle = '--', linewidth = 0.5);

# %%
# Evaluate the Model on the Test Data
model_performance = model.evaluate(X_test, y_test)
print(f'Test Loss: {model_performance[0]} | Test Accuracy: {round(model_performance[1]*100, 2)}%')
# Out:
# 313/313 [==============================] - 2s 7ms/step - loss: 386.0341 - accuracy: 0.4390
# Test Loss: 386.0340881347656 | Test Accuracy: 43.9%

# %%
prediction = model.predict(X_test)

def predict_image(index, label_dict):

  fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(25, 2))
  x, y = list(label_dict.values()), prediction[index]

  ax1.imshow(tf.squeeze(X_test[index]));
  ax2.bar(x, y);

  ax2.set_xticks(x);
  ax2.set_ylabel('Probability Score');
  ax2.set_xlabel('Image');

# %%
index = [0, 1, 2, 3, 4]

for i in index:
  predict_image(i, label_dict)
