# %% [markdown]
# ## Loading and Reading the data

# %%
# Load dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Read dataset
import pandas as pd

train = pd.read_csv("/content/drive/MyDrive/Deep Learning/fake-news/train.csv")
test = pd.read_csv("/content/drive/MyDrive/Deep Learning/fake-news/test.csv")

# %%
# Shape of train and test data
print(f'Train shape {train.shape}')
print(f'Test shape {test.shape}')
# Out:
# Train shape (20800, 5)
# Test shape (5200, 4)

# %%
train.head()
# Out:
#    id  ... label
# 0   0  ...     1
# 1   1  ...     0
# 2   2  ...     1
# 3   3  ...     1
# 4   4  ...     1
#
# [5 rows x 5 columns]

# %% [markdown]
# There are 5 columns. ID and Author columns are not useful, we will not conider them. Label is the dependent variable. 1 means unreliable and 0 means reliable news.

# %%
# Checking NaN values
train.isnull().values.any()
# Out:
# True

# %%
# Dropping NaN values. Since this is a text data, we cannot fill NaN values.
train = train.filter(['text', 'label'])
train.reset_index(drop=True, inplace=True)
train.dropna(inplace=True)
train.shape
# Out:
# (20761, 2)

# %%
# Dependent and Independent Features
X = train['text']
y = train['label']

# %%
# Checking value counts
print(f'Value counts in percentage terms:\n{round(y.value_counts(normalize=True)*100, 2)}')
# Out:
# Value counts in percentage terms:
# 0    50.03
# 1    49.97
# Name: label, dtype: float64

# %% [markdown]
# We have 50.03% of points belonging to reliable news category and 49.97% of data points labelled as unreliable data. We can consider this data without balancing it.

# %% [markdown]
# ## Normalizing the text data

# %%
# Required libraries for preprocessing text data
import re
import nltk
from tqdm import tqdm
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

nltk.download('punkt')
nltk.download('stopwords')
stemming = PorterStemmer()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def normalize(data):
    
  i = data.lower()                            # Lower case
  i = re.sub('https?://\S+|www\.\S+', '', i)  # Remove urls
  i = re.sub('\\W', ' ', i)                   # Remove white spaces and non words
  i = re.sub(r'\d+', '', i)                   # Remove numbers
  i = re.sub('\n', '', i)
  i = re.sub(' +', ' ', i)
  i = re.sub('^ ', '', i)
  i = re.sub(' $', '', i)

  # Tokenzing and stopword removal
  text_tokens = word_tokenize(i)
  tokens_without_sw = [word for word in text_tokens if not word in stopwords.words()]
  filtered_sentence = (" ").join(tokens_without_sw)

  # Stemming
  text_tokens = word_tokenize(filtered_sentence)
  stemmed_tokens = [stemming.stem(word) for word in text_tokens]
  normalized_text = (" ").join(stemmed_tokens)
  return normalized_text

X_norm = X.apply(normalize)

# %%
X_df = pd.DataFrame({'Text': X_norm})
X_df.to_csv('normalized_vals.csv', index=False)

# %%
X_norm = pd.read_csv("/content/drive/MyDrive/Deep Learning/normalized_vals.csv")
X_norm = X_norm['Text'].astype("str")

# %% [markdown]
# ## Encoding

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2
#  1710  325 1916 2264 2920 1784 3577  448 3577 2771 1168 4764 1900 1318
#   695 3073 1419 4784 1710  249 2562 2685  978 3073 1045 3758 4796 4286
#  4764 3817 3748 3073  978 3312 3854 3481 4961 3846 4973 2976 2596 4564
#  1710 2440 1829 3256 3456 2759  238  695 4550 3990 2974 3275 3709 3687
#  3409 1653   56 3687 3846 1710 4380 3577 3256 2060 4891 1784 4588 4399
#   249 2165 4763 4132 3833 1787 4423 2153  980 3976 3173  974  342 2974
#  1710 3695 3976  348 1346 2137  980  616  978 1045  974 3258 2371 2392
#  3033  980  775 4281  288 2625 3439 1045  974 1829 1839 2596  980  775
#  4281 3439 3857 2299  761  664 2625 4784 1710 1784 2513 4618 4208  778
#   273  361 3577  843 4083 1710 2616 2625 1839 4038 1810 4809 1916  733
#   695 1371 1710 1884 3547 4208  980 3913  978 1755 1787 3976 2513 2964
#  3033 3256 3334 1693  822 1045 3425 3676  246  974 1710 1829 1856 3258
#  4024 1643 1640  342 4264  986  556 3585 1978  616 4808 3073 3585 1978
#  4808 1045 1287 3371 2557 3140 2941 4808 4548 1710  589 4435 4264 4035
#  4455 3411 4568   75 4686 1365 1449  616 3193  505  775 4281 3574 3768
#  1721  733 4919 2863  973 1756  978 3672   75 1710 2816  623 2636 1829
#  4465 1723 4333 1143 1757   61 2141 4717  177 4974  563 2338 3454 2141
#  2181 1829 2153 1910 4134 3724 3681 1710   59 4022 4101  196 4024 3928
#  3817 2306 3688 2153 1504 1829 1737 2517 1075 1850 2264 4455 3504 4455
#  1721 1367  477 1718 3095 1914 1527 3188 1986 1830 4024 4281 1782  361
#  4801 2564 4024 1782  361 1075 3929 3996   44 4757 1347 3709  759 2633
#   260 1008 1215  478 4794 3709 4562  342  978 1693  822   44 1976  134
#  3033 1506 1123 3889 1241 3392 4455 4834  878 1123]

# %% [markdown]
# ## Train Test Split

# %%
import numpy as np
X = np.array(embedded_repr)
y = np.array(y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

# %% [markdown]
# ## Building Bidirectional RNN

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, 50, input_length=500),  # Taking 50 features for embedding and input length is 500 because we are considering 500 words.
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64,  return_sequences=True)),
    tf.keras.layers.Dense(32, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(16, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(1)
])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics='accuracy')
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 500, 50)           250000
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 500, 128)          58880
# _________________________________________________________________
# dense_6 (Dense)              (None, 500, 32)           4128
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 500, 32)           128
# _________________________________________________________________
# dense_7 (Dense)              (None, 500, 16)           528
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 500, 16)           0
# _________________________________________________________________
# dense_8 (Dense)              (None, 500, 1)            17
# =================================================================
# Total params: 313,681
# Trainable params: 313,617
# Non-trainable params: 64
# _________________________________________________________________

# %%
model.fit(X_train, y_train, batch_size = 128, validation_data=(X_test, y_test), epochs = 20)
# Out:
# Epoch 1/20
# 114/114 [==============================] - 14s 93ms/step - loss: 1.1274 - accuracy: 0.5759 - val_loss: 1.0493 - val_accuracy: 0.5051
# Epoch 2/20
# 114/114 [==============================] - 10s 85ms/step - loss: 0.6772 - accuracy: 0.6758 - val_loss: 0.6835 - val_accuracy: 0.6021
# Epoch 3/20
# 114/114 [==============================] - 10s 86ms/step - loss: 0.7514 - accuracy: 0.7096 - val_loss: 7.3186 - val_accuracy: 0.4981
# Epoch 4/20
# 114/114 [==============================] - 10s 87ms/step - loss: 0.8246 - accuracy: 0.6231 - val_loss: 6.8409 - val_accuracy: 0.5066
# Epoch 5/20
# 114/114 [==============================] - 10s 86ms/step - loss: 0.6712 - accuracy: 0.7093 - val_loss: 0.5772 - val_accuracy: 0.8140
# Epoch 6/20
# 114/114 [==============================] - 10s 88ms/step - loss: 0.5661 - accuracy: 0.8192 - val_loss: 0.5710 - val_accuracy: 0.8963
# Epoch 7/20
# 114/114 [==============================] - 10s 89ms/step - loss: 0.5756 - accuracy: 0.7823 - val_loss: 3.6171 - val_accuracy: 0.5373
# Epoch 8/20
# 114/114 [==============================] - 10s 89ms/step - loss: 0.7339 - accuracy: 0.6567 - val_loss: 6.9454 - val_accuracy: 0.4941
# Epoch 9/20
# 114/114 [==============================] - 10s 88ms/step - loss: 0.6604 - accuracy: 0.6691 - val_loss: 1.0496 - val_accuracy: 0.5823
# Epoch 10/20
# 114/114 [==============================] - 10s 89ms/step - loss: 0.6430 - accuracy: 0.6850 - val_loss: 0.8589 - val_accuracy: 0.5186
# Epoch 11/20
# 114/114 [==============================] - 10s 88ms/step - loss: 0.5735 - accuracy: 0.7490 - val_loss: 7.2923 - val_accuracy: 0.5081
# Epoch 12/20
# 114/114 [==============================] - 10s 87ms/step - loss: 0.6229 - accuracy: 0.7105 - val_loss: 2.3913 - val_accuracy: 0.7091
# Epoch 13/20
# 114/114 [==============================] - 10s 89ms/step - loss: 0.6170 - accuracy: 0.7194 - val_loss: 0.7024 - val_accuracy: 0.5446
# Epoch 14/20
# 114/114 [==============================] - 10s 89ms/step - loss: 0.5461 - accuracy: 0.7598 - val_loss: 0.5687 - val_accuracy: 0.7179
# Epoch 15/20
# 114/114 [==============================] - 10s 88ms/step - loss: 0.5522 - accuracy: 0.7522 - val_loss: 1.2329 - val_accuracy: 0.5634
# Epoch 16/20
# 114/114 [==============================] - 10s 89ms/step - loss: 0.5471 - accuracy: 0.7543 - val_loss: 0.8993 - val_accuracy: 0.5659
# Epoch 17/20
# 114/114 [==============================] - 10s 88ms/step - loss: 0.5162 - accuracy: 0.7690 - val_loss: 4.7375 - val_accuracy: 0.5169
# Epoch 18/20
# 114/114 [==============================] - 10s 88ms/step - loss: 0.4753 - accuracy: 0.8059 - val_loss: 2.5310 - val_accuracy: 0.7584
# Epoch 19/20
# 114/114 [==============================] - 10s 89ms/step - loss: 0.4523 - accuracy: 0.8264 - val_loss: 2.2296 - val_accuracy: 0.5411
# Epoch 20/20
# 114/114 [==============================] - 10s 88ms/step - loss: 0.2994 - accuracy: 0.9114 - val_loss: 0.5599 - val_accuracy: 0.9057

# %%
model.evaluate(X_test, y_test)
# Out:
# 195/195 [==============================] - 5s 26ms/step - loss: 0.5599 - accuracy: 0.9057
# [0.559907853603363, 0.9056671857833862]
